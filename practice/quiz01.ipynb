# %%
print("Hello, World! This is a sample code snippet.")
print("This code is for demonstration purposes only.")
print("It does not perform any meaningful operations.")
# Out:
# Hello, World! This is a sample code snippet.
# This code is for demonstration purposes only.
# It does not perform any meaningful operations.
