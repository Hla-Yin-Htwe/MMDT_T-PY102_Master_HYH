# %%
class solution:
    def isValid(self, s: str) -> bool:
        pair_dict = {')': '(', '}': '{', ']': '['}
        stack_list = []
        for char in s:
            print("current char is ",char)
            if char in pair_dict:
                if (len(stack_list) == 0):
                    print("Closing char is found")
                    print("but stack is empty")
                    return False
                top = stack_list[-1]
                print("the last (top) one in stack is ",top)

                if top != pair_dict[char]:
                    print("Opening is ",top)
                    print("closing is",char)
                    return False
                stack_list.pop()
                print("remove last char",top)
                print(stack_list)
            else:
                stack_list.append(char)
                print("add char on top(stack)")
                print(stack_list)
        return True

sol = solution()
sol.isValid("[{(3)}]")

# print(sol.isValid("()[]{}"))
# Out:
# current char is  [
# add char on top(stack)
# ['[']
# current char is  {
# add char on top(stack)
# ['[', '{']
# current char is  (
# add char on top(stack)
# ['[', '{', '(']
# current char is  3
# add char on top(stack)
# ['[', '{', '(', '3']
# current char is  )
# the last (top) one in stack is  3
# Opening is  3
# closing is )
# False
