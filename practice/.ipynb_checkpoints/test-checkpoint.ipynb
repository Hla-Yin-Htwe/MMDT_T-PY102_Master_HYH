# %% [markdown]
# scores=new list()
# Append(scores, 70)
# Append(scores, 85)
# Append(scores, 90)
#
# print(scores)
# Insert(scores, 1, 80)
# print(scores)

# %%
#Using Lists in Pythons
scores=[]
scores.append(70)
scores.append(85)
scores.append(90)

print(scores)
scores.insert(1,80)
print(scores)
# Out:
# [70, 85, 90]
# [70, 80, 85, 90]
