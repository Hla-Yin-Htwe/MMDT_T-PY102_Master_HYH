# %% [markdown]
# scores=new list()
# Append(scores, 70)
# Append(scores, 85)
# Append(scores, 90)
#
# print(scores)
# Insert(scores, 1, 80)
# print(scores)

# %%
#Using Lists in Pythons
scores=[]
scores.append(70)
scores.append(85)
scores.append(90)

print(scores)
scores.insert(1,80)
print(scores)
# Out:
# [70, 85, 90]
# [70, 80, 85, 90]

# %%
#LinkedList Node
class Node:
    def __init__(self, value):
        self.data=value
        self.next: Node | None=None

# %%
#Singly Linkedlist
class SinglyLinkedlist:
    def __init__(self):
        self.head=None
        self.tail=None

# %%
num_list=SinglyLinkedlist()
# num_list.append(32)

# %%
class SinglyLinkedList():
    def __init__(self):
        self.head: Node | None = None
        self.tail: Node | None = None
        
    def append(self, data):
        new_node=Node (data)
        if self.head is None:
            self.head =new_node
            self.tail==new_node
        else:
            assert self.tail is not None
            self.tail.next=new_node
            self.tail=new_node

    def insert(self, crtdata, newdata):
        hostnode = self.search(crtdata)
        if hostnode is not None:
            new_node = Node(newdata)
            new_node.next = hostnode.next
            hostnode.next = new_node
            return True
        return False
    
    def printnodevalue(self):
        node = self.head
        count = 0
        while node is not None:
            print(f"value is {node.data}")
            print(f"current node's address {id(node)}")
            print(f"this node points to {id(node.next)}")
            node = node.next
            count +=1
        
        print('Number of node is', count)
        
num_list = SinglyLinkedList()
num_list.append(16)
num_list.insert(0,58)
num_list.printnodevalue()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 38
#      35         print('Number of node is', count)
#      37 num_list = SinglyLinkedList()
# ---> 38 num_list.append(16)
#      39 num_list.insert(0,58)
#      40 num_list.printnodevalue()
#
# Cell In[2], line 7, in SinglyLinkedList.append(self, data)
#       6 def append(self, data):
# ----> 7     new_node=Node (data)
#       8     if self.head is None:
#       9         self.head =new_node
#
# NameError: name 'Node' is not defined

# %%
class MinStack:

    def __init__(self):
        self.stack = []
        self.min_stack = []

    def push(self, val: int) -> None:
        self.stack.append(val)

        if not self.min_stack or val <= self.min_stack[-1]:
            self.min_stack.append(val)

    def pop(self) -> None:
        removed = self.stack.pop()

        if removed == self.min_stack[-1]:
            self.min_stack.pop()

    def top(self) -> int:
        return self.stack[-1]

    def getMin(self) -> int:
        return self.min_stack[-1]

minStack = MinStack()
minStack.push(-2)
minStack.push(0)
minStack.push(-3)
print(minStack.getMin())  # -3
minStack.pop()
print(minStack.top())     # 0
print(minStack.getMin())  # -2
# Out:
# -3
# 0
# -2
